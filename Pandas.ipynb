# %%
import pandas as pd

df = pd.read_csv('data.csv')

# cau1 = df[df['Percentage'] > 80]
  
# print('\nResult dataframe :\n', cau1)

# %%
for i in df:
    print(i)
#     for j in df[i]:
#         if type(j) == str:
#             if '> 2000 mg/kg bw' in j or '5000 mg/kg bw' in j:
#                 print(df[df[i]])
# Out:
# Name
# Active substance (iso common name)
# Function (e.g. fungicide)
# Rapporteur member state
# Co-rapporteur member state
# Chemical name (IUPAC)
# Chemical name (CA)
# CAS no
# Identity of relevant
# Rate and extent of absorption
# Distribution
# Potential for accumulation
# Rate and extent of excretion
# Metabolism in animals
# Toxicologically relevant compounds1
# Toxicologically relevant compounds2
# LD50 oral
# LD50 dermal
# LC50 inhalation
# Skin irritation
# Eye irritation
# Summary
# Background
# Concerns

# %%
# cau1 = df[(df['LD50 dermal'] == '> 2000 mg/kg bw') | (df['LD50 dermal'] == '5000 mg/kg bw')]
# cau1

# %%
newdf = df[['Active substance (iso common name)', 'LD50 dermal','Concerns']]
newdf[(newdf['LD50 dermal'] == '> 2000 mg/kg bw') & (newdf['Concerns'] == 'Concerns are identified')]
# Out:
#                     Active substance (iso common name)      LD50 dermal  \
# 19   fosetyl (unless otherwise specified the follow...  > 2000 mg/kg bw
# 289         potassium thiocyanate (no iso common name)  > 2000 mg/kg bw
# 325  active substance (iso common 1,4-dimethylnapht...  > 2000 mg/kg bw
# 344                                       tebuconazole  > 2000 mg/kg bw
# 359                      flumioxazin (iso common name)  > 2000 mg/kg bw
# 368                                        prosulfuron  > 2000 mg/kg bw
# 369                                        pymetrozine  > 2000 mg/kg bw
# 390                                   benzovindiflupyr  > 2000 mg/kg bw
# 396                          famoxadone (iso approved)  > 2000 mg/kg bw
# 404  isofetamid (provisionally approved by the iso ...  > 2000 mg/kg bw
# 410    ethofumesate (iso 1750, published), no synonyms  > 2000 mg/kg bw
# 411                                   fenamidone (iso)  > 2000 mg/kg bw
# ...
